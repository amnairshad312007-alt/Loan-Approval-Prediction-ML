# %% [markdown]
# <a href="https://colab.research.google.com/github/amnairshad312007-alt/Loan-Approval-Prediction-ML/blob/main/Loan_Approval_Prediction_Using_Machine_Learning_ipynp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Import Libraries

# %%
# Data Handling
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Evaluation
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# Step 2: Dataset Load

# %%
df=pd.read_csv('/content/loan_approval_dataset.csv')

# %% [markdown]
# Step 3: First Five Rows

# %%
df.head(5)

# %% [markdown]
# Step 4: Last Five Rows

# %%
df.tail(5)

# %% [markdown]
# Step 5: Dataset Shape

# %%
print (df.shape)

# %% [markdown]
# 4269 Rows
# 13 Columns

# %% [markdown]
# Step 6: Columns Names

# %%
df.columns

# %% [markdown]
# Step 7: Dataset Information

# %%
df.info()

# %% [markdown]
# Step 8: Statistical Summary

# %%
df.describe()

# %% [markdown]
# #Is se Mean, Min, Max, Standard Deviation waghera milta hai.

# %% [markdown]
# Step 9: Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# Step 10: Duplicate Values

# %%
print(df.duplicated().sum())

# %% [markdown]
# Column Names Clean

# %%
df.columns=df.columns.str.strip()

# %% [markdown]
# Label Encoding

# %% [markdown]
# Text ko numbers mein convert karenge.

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

df["education"]=le.fit_transform(df["education"])

df["self_employed"]=le.fit_transform(df["self_employed"])

df["loan_status"]=le.fit_transform(df["loan_status"])

# %% [markdown]
# Features aur Target

# %%
X=df.drop(["loan_id","loan_status"],axis=1)

y=df["loan_status"]

# %% [markdown]
# Shape Check

# %%
print(X.shape)

print(y.shape)

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(
X,
y,
test_size=0.20,
random_state=42
)

# %% [markdown]
# Check

# %%
print(X_train.shape)

print(X_test.shape)

# %% [markdown]
#  Exploratory Data Analysis (EDA)

# %% [markdown]
# Cell 1: Loan Status Count

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x="loan_status",data=df)
plt.title("Loan Status Distribution")
plt.show()

# %% [markdown]
# Cell 2: Education

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="education",data=df)
plt.title("Education Distribution")
plt.show()

# %% [markdown]
# Cell 3: Self Employed

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="self_employed",data=df)
plt.title("Self Employed Distribution")
plt.show()

# %% [markdown]
# Cell 4: Income Distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["income_annum"],bins=30)
plt.title("Annual Income Distribution")
plt.show()

# %% [markdown]
# Cell 5: CIBIL Score

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["cibil_score"],bins=30)
plt.title("CIBIL Score Distribution")
plt.show()

# %% [markdown]
# Cell 6: Correlation Heatmap

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# model apply
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression(max_iter=1000)

lr.fit(X_train,y_train)

lr_pred=lr.predict(X_test)

# %% [markdown]
# Accuracy

# %%
from sklearn.metrics import accuracy_score

lr_acc=accuracy_score(y_test,lr_pred)

print("Logistic Regression Accuracy :",lr_acc)

# %% [markdown]
# Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,lr_pred))

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,lr_pred)

sns.heatmap(cm,annot=True,fmt="d")

plt.title("Logistic Regression")

plt.show()
